# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
from numpy import random, float, array
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\dell\\shi\\crime_data.csv')
df.head()
# Out:
#    STATE/UT        DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  DELHI UT         CENTRAL  2001      29                 42
# 1  DELHI UT            EAST  2001      56                 51
# 2  DELHI UT     G.R.P.(RLY)  2001      11                  4
# 3  DELHI UT  I.G.I. AIRPORT  2001       2                  2
# 4  DELHI UT       NEW DELHI  2001      11                 14
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                          4    28               0
# 1                                         15    24               0
# 2                                          0     1               0
# 3                                          1     0               0
# 4                                          0     9               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          28                      62  ...      1                 113
# 1          24                     163  ...      4                 257
# 2           1                       7  ...      0                   7
# 3           0                       4  ...      1                   5
# 4           9                      27  ...      3                  35
#
#    DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 0             4                                                 30
# 1            11                                                 56
# 2             0                                                  4
# 3             0                                                  0
# 4             0                                                 20
#
#    INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 0                           7                                    2
# 1                          11                                   27
# 2                           0                                    0
# 3                           2                                    0
# 4                           6                                    2
#
#    IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 0                                            0                           13
# 1                                            0                           23
# 2                                            0                            0
# 3                                            0                            2
# 4                                            0                          109
#
#    OTHER IPC CRIMES  TOTAL IPC CRIMES
# 0              1422              3750
# 1              1552              4447
# 2               129              1630
# 3                61               625
# 4               731              2660
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (208, 33)

# %%
df[df.isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [STATE/UT, DISTRICT, YEAR, MURDER, ATTEMPT TO MURDER, CULPABLE HOMICIDE NOT AMOUNTING TO MURDER, RAPE, CUSTODIAL RAPE, OTHER RAPE, KIDNAPPING & ABDUCTION, KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS, KIDNAPPING AND ABDUCTION OF OTHERS, DACOITY, PREPARATION AND ASSEMBLY FOR DACOITY, ROBBERY, BURGLARY, THEFT, AUTO THEFT, OTHER THEFT, RIOTS, CRIMINAL BREACH OF TRUST, CHEATING, COUNTERFIETING, ARSON, HURT/GREVIOUS HURT, DOWRY DEATHS, ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY, INSULT TO MODESTY OF WOMEN, CRUELTY BY HUSBAND OR HIS RELATIVES, IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES, CAUSING DEATH BY NEGLIGENCE, OTHER IPC CRIMES, TOTAL IPC CRIMES]
# Index: []
#
# [0 rows x 33 columns]

# %%
stats = df.sort_values("TOTAL IPC CRIMES", ascending=False)
stats
# Out:
#      STATE/UT      DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 68   DELHI UT    NORTH-WEST  2006     128                151
# 56   DELHI UT    NORTH-WEST  2005     128                121
# 69   DELHI UT         SOUTH  2006      66                 69
# 9    DELHI UT         SOUTH  2001      83                 75
# 57   DELHI UT         SOUTH  2005      67                 63
# ..        ...           ...   ...     ...                ...
# 191  Delhi UT          East  2014      61                 93
# 190  Delhi UT  Crime Branch  2014       0                  3
# 189  Delhi UT       Central  2014      30                 44
# 8    DELHI UT        S.T.F.  2001       0                  0
# 207  Delhi UT          West  2014      55                 77
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 68                                          12   169               0
# 56                                          18   190               0
# 69                                          13    87               0
# 9                                            7    65               0
# 57                                           6    87               0
# ..                                         ...   ...             ...
# 191                                          5   185             230
# 190                                          0     0               1
# 189                                         11    62              91
# 8                                            0     0               0
# 207                                          6   101             251
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 68          169                     437  ...      4                 358
# 56          190                     572  ...      6                 333
# 69           87                     215  ...      5                 206
# 9            65                     265  ...     10                 307
# 57           87                     231  ...      4                 214
# ..          ...                     ...  ...    ...                 ...
# 191           0                       0  ...      2                   0
# 190           0                       0  ...      0                   0
# 189           0                       0  ...      4                   0
# 8             0                       0  ...      0                   0
# 207           0                       0  ...      5                   1
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 68             28                                                137
# 56             23                                                138
# 69             19                                                141
# 9              15                                                 96
# 57             19                                                151
# ..            ...                                                ...
# 191           789                                                999
# 190             0                                                  0
# 189           288                                                576
# 8               0                                                  0
# 207           580                                                972
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 68                           11                                  412
# 56                           53                                  324
# 69                           34                                  215
# 9                            24                                   22
# 57                           36                                  188
# ..                          ...                                  ...
# 191                         600                                  399
# 190                           0                                    0
# 189                         345                                  231
# 8                             0                                    0
# 207                         709                                  263
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 68                                             0                           48
# 56                                             0                           21
# 69                                             0                           49
# 9                                              0                          103
# 57                                             0                           34
# ..                                           ...                          ...
# 191                                         9437                         3113
# 190                                            0                            0
# 189                                         4124                         1132
# 8                                              0                            0
# 207                                         9404                         3351
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 68               5704             11146
# 56               5531             11019
# 69               4907             10854
# 9                3991             10745
# 57               4454             10529
# ..                ...               ...
# 191              6324                 0
# 190                 0                 0
# 189              2992                 0
# 8                   0                 0
# 207              6053                 0
#
# [208 rows x 33 columns]

# %%
x = df['DISTRICT']
real_x = x.unique()
print(real_x)
# Out:
# ['CENTRAL' 'EAST' 'G.R.P.(RLY)' 'I.G.I. AIRPORT' 'NEW DELHI' 'NORTH'
#  'NORTH EAST' 'NORTH WEST' 'S.T.F.' 'SOUTH' 'SOUTH WEST' 'WEST' 'SPL CELL'
#  'IGI AIRPORT' 'NORTH-EAST' 'NORTH-WEST' 'SOUTH-WEST' 'GRP(RLY)' 'STF'
#  'OUTER' 'CAW' 'CRIME BRANCH' 'EOW' 'SOUTH-EAST' 'METRO RAIL' 'Central'
#  'Crime Branch' 'East' 'IGI Airport' 'Metro' 'New Delhi' 'North'
#  'North-East' 'North-West' 'Outer' 'RAILWAY' 'South' 'South-East'
#  'South-West' 'Spl Cell' 'SPUWAC' 'Vigilance' 'West']
