# %%
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from streamlit_folium import folium_static
import folium

# %%
data_url=('C:\\Users\\dell\\crimeproject\\crime_data_1.csv')
data=pd.read_csv(data_url)
data
# Out:
#      STATE/UT     DISTRICT  ARSON  CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  \
# 0    DELHI UT         EAST      4                                         15
# 1    DELHI UT     GRP(RLY)      0                                          0
# 2    DELHI UT  IGI AIRPORT      1                                          1
# 3    DELHI UT    NEW DELHI      3                                          0
# 4    DELHI UT        NORTH      3                                          5
# ..        ...          ...    ...                                        ...
# 183  Delhi UT   SOUTH WEST     10                                          5
# 184  Delhi UT        OUTER      0                                          0
# 185  Delhi UT        OUTER      0                                          0
# 186  Delhi UT        OUTER      0                                          0
# 187  Delhi UT         WEST      5                                          6
#
# ...

# %%
st.title("Crime Insights of Delhi")
st.markdown("This application exploits Data analytics techniques to give useful insights to people so that they can be safe and have information about unknown areas they have to visit..")

# %%
# !streamlit run app.py
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
#
# Error: Invalid value: File does not exist: app.py
